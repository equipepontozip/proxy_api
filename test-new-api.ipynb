# %%
import pandas as pd
import json
from urllib import request

# %%
ORIGINAL_URL = "https://www.sistemas.dftrans.df.gov.br/service/gps/operacoes"

# %%
req = request.Request(ORIGINAL_URL, method='GET')
print('Requesting on %s' % ORIGINAL_URL)

response = request.urlopen(req)
body = response.read().decode('utf-8')
body = json.loads(body)

#df = pd.DataFrame.from_records(body['Dados'], columns=body['Campos'])
# Out:
# Requesting on https://www.sistemas.dftrans.df.gov.br/service/gps/operacoes

# %%
df = pd.DataFrame()
for operadora in body:
    df_temp = pd.DataFrame.from_records(operadora['veiculos'])
    df = pd.concat([df,df_temp], ignore_index=True)

# %%
print(df.shape)
df.head()
# Out:
# (2588, 9)
#   codigoImei  direcao        horario  linha  \
# 0    7324128    250.0  1573717250000
# 1    7319233    249.0  1573920609000
# 2    7490231    268.0  1573940137000
# 3    7320218    270.0  1574373554000  844.1
# 4    7531250     37.0  1574373680000  0.882
#
#                                        localizacao  numero sentido  valid  \
# 0  {'latitude': -15.89937, 'longitude': -48.12278}  333468   VOLTA   True
# 1  {'latitude': -15.87006, 'longitude': -48.09042}  333824     IDA   True
# 2  {'latitude': -15.81855, 'longitude': -47.98433}  331163   VOLTA   True
# 3  {'latitude': -15.79103, 'longitude': -48.03869}  333786   VOLTA   True
# 4  {'latitude': -15.89631, 'longitude': -48.04774}  332054     IDA   True
#
#                                    velocidade
# 0      {'unidade': 'KM_POR_HORA', 'valor': 0}
# 1      {'unidade': 'KM_POR_HORA', 'valor': 0}
# 2  {'unidade': 'KM_POR_HORA', 'valor': 11.94}
# 3   {'unidade': 'KM_POR_HORA', 'valor': 1.11}
# 4      {'unidade': 'KM_POR_HORA', 'valor': 0}

# %%
df_lat_long = df.localizacao.apply(pd.Series)
df = df.merge(df_lat_long, on=df.index)

# %%
df.head()
# Out:
#    key_0 codigoImei  direcao        horario  linha  \
# 0      0    7324128    250.0  1573717250000
# 1      1    7319233    249.0  1573920609000
# 2      2    7490231    268.0  1573940137000
# 3      3    7320218    270.0  1574373554000  844.1
# 4      4    7531250     37.0  1574373680000  0.882
#
#                                        localizacao  numero sentido  valid  \
# 0  {'latitude': -15.89937, 'longitude': -48.12278}  333468   VOLTA   True
# 1  {'latitude': -15.87006, 'longitude': -48.09042}  333824     IDA   True
# 2  {'latitude': -15.81855, 'longitude': -47.98433}  331163   VOLTA   True
# 3  {'latitude': -15.79103, 'longitude': -48.03869}  333786   VOLTA   True
# 4  {'latitude': -15.89631, 'longitude': -48.04774}  332054     IDA   True
#
#                                    velocidade  latitude  longitude
# 0      {'unidade': 'KM_POR_HORA', 'valor': 0} -15.89937  -48.12278
# 1      {'unidade': 'KM_POR_HORA', 'valor': 0} -15.87006  -48.09042
# 2  {'unidade': 'KM_POR_HORA', 'valor': 11.94} -15.81855  -47.98433
# 3   {'unidade': 'KM_POR_HORA', 'valor': 1.11} -15.79103  -48.03869
# 4      {'unidade': 'KM_POR_HORA', 'valor': 0} -15.89631  -48.04774
